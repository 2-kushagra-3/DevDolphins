# %%
import pandas as pd
import os
from datetime import datetime
import re

gender_summary_df = pd.DataFrame(columns=['merchant', 'customer', 'gender'])
already_detected_pat3 = set()


def print_gender_conflicts(df):
    gender_counts = df.groupby(['merchant', 'customer'])['gender'].nunique().reset_index()
    conflicts = gender_counts[gender_counts['gender'] > 1]

    if conflicts.empty:
        print("\n✅ No gender conflicts found.")
        return

    print(f"\n⚠️ Found {len(conflicts)} gender conflicts across chunks:")
    for _, row in conflicts.iterrows():
        merchant = row['merchant']
        customer = row['customer']
        all_genders = df[(df['merchant'] == merchant) & (df['customer'] == customer)]['gender'].unique()
        print(f" - Merchant: {merchant}, Customer: {customer}, Genders: {list(all_genders)}")

def detect_patid3():
    detections = []

    global gender_summary_df
    # Drop conflicting gender entries
    gender_counts = gender_summary_df.groupby(['merchant', 'customer'])['gender'].nunique().reset_index()
    conflict_keys = gender_counts[gender_counts['gender'] > 1][['merchant', 'customer']].apply(tuple, axis=1)
    gender_summary_df['key'] = list(zip(gender_summary_df['merchant'], gender_summary_df['customer']))
    gender_summary_df = gender_summary_df[~gender_summary_df['key'].isin(conflict_keys)]
    gender_summary_df.drop(columns='key', inplace=True)

    # Group by merchant & gender
    gender_counts = gender_summary_df.groupby(['merchant', 'gender'])['customer'].nunique().reset_index(name='count')
    pivot_df = gender_counts.pivot(index='merchant', columns='gender', values='count').fillna(0).reset_index()
    pivot_df.columns.name = None

    if 'F' not in pivot_df.columns:
        pivot_df['F'] = 0
    if 'M' not in pivot_df.columns:
        pivot_df['M'] = 0

    print("\n📟 Gender distribution per merchant (top 10):")
    print(pivot_df[['merchant', 'F', 'M']].sort_values(by='F', ascending=False).head(10))

    eligible = pivot_df[(pivot_df['F'] > 100) & (pivot_df['F'] < pivot_df['M'])]

    print("\n🌟 Eligible DEI-NEEDED merchants:")
    print(eligible[['merchant', 'F', 'M']])

    now = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    for _, row in eligible.iterrows():
        merchant_id = row['merchant']
        if merchant_id in already_detected_pat3:
            continue

        detections.append({
            "YStartTime": now,
            "detectionTime": now,
            "patternId": "PatId3",
            "ActionType": "DEI-NEEDED",
            "customerName": "",
            "MerchantId": merchant_id
        })
        already_detected_pat3.add(merchant_id)

    return pd.DataFrame(detections)

def write_detections(detections, output_dir="outputs/", file_prefix="detections_pat3"):
    if detections.empty:
        return

    os.makedirs(output_dir, exist_ok=True)

    for i in range(0, len(detections), 50):
        batch = detections.iloc[i:i+50]
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S_%f')
        output_path = f"{output_dir}/{file_prefix}_{timestamp}.csv"
        batch.to_csv(output_path, index=False)
        print(f"✅ Wrote {len(batch)} detections to {output_path}")

def chunk_key(filename):
    match = re.search(r"chunk_(\d+)_", filename)
    return int(match.group(1)) if match else float('inf')

def main():
    chunk_folder = r"C:\\Users\\kusha\\OneDrive\\Desktop\\Projects\\DevDolphins\\Blob files\\Chunks"
    all_files = sorted(os.listdir(chunk_folder), key=chunk_key)

    global gender_summary_df

    for file in all_files:
        print(f"\n📦 Processing: {file}")
        chunk_df = pd.read_csv(os.path.join(chunk_folder, file))
        chunk_df['gender'] = (
            chunk_df['gender']
            .astype(str)
            .str.replace("'", "")
            .str.strip()
            .str.upper()
        )

        chunk_gender_df = chunk_df[['merchant', 'customer', 'gender']].dropna()
        gender_summary_df = pd.concat([gender_summary_df, chunk_gender_df], ignore_index=True)
        gender_summary_df.drop_duplicates(subset=['merchant', 'customer', 'gender'], inplace=True)

        print_gender_conflicts(gender_summary_df)

        detections = detect_patid3()
        write_detections(detections)

if __name__ == "__main__":
    main()
# Out:
# 📦 Processing: chunk_1_20250624_202535.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F      M
# 26   'M348934600'  1108.0  911.0
# 15  'M1823072687'   318.0  263.0
# 39   'M855959430'   110.0   93.0
# 8    'M151143676'   109.0   85.0
# 41    'M85975013'   100.0   83.0
# 30   'M480139044'    54.0   46.0
# 23   'M209847108'    54.0   50.0
# 9   'M1535107174'    47.0   38.0
# 0   'M1053599405'    37.0   29.0
# 10  'M1600850729'    33.0   21.0
#
# 🌟 Eligible DEI-NEEDED merchants:
# Empty DataFrame
# Columns: [merchant, F, M]
# Index: []
#
# 📦 Processing: chunk_2_20250624_202537.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F      M
# 27   'M348934600'  1170.0  965.0
# 15  'M1823072687'   412.0  336.0
# 40   'M855959430'   225.0  163.0
# 8    'M151143676'   206.0  185.0
# 42    'M85975013'   175.0  141.0
# 24   'M209847108'   122.0  101.0
# 31   'M480139044'   109.0   75.0
# 9   'M1535107174'    82.0   68.0
# 10  'M1600850729'    66.0   44.0
# 0   'M1053599405'    63.0   58.0
#
# 🌟 Eligible DEI-NEEDED merchants:
# Empty DataFrame
# Columns: [merchant, F, M]
# Index: []
#
# 📦 Processing: chunk_3_20250624_202539.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F       M
# 29   'M348934600'  1223.0  1012.0
# 17  'M1823072687'   470.0   383.0
# 9    'M151143676'   312.0   257.0
# 42   'M855959430'   292.0   229.0
# 44    'M85975013'   245.0   193.0
# 26   'M209847108'   169.0   142.0
# 33   'M480139044'   151.0    97.0
# 10  'M1535107174'   116.0    97.0
# 0   'M1053599405'    91.0    76.0
# 11  'M1600850729'    89.0    66.0
#
# 🌟 Eligible DEI-NEEDED merchants:
# Empty DataFrame
# Columns: [merchant, F, M]
# Index: []
#
# 📦 Processing: chunk_4_20250624_202540.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F       M
# 29   'M348934600'  1272.0  1051.0
# 17  'M1823072687'   535.0   440.0
# 9    'M151143676'   382.0   322.0
# 42   'M855959430'   372.0   307.0
# 44    'M85975013'   299.0   251.0
# 26   'M209847108'   217.0   178.0
# 33   'M480139044'   189.0   132.0
# 10  'M1535107174'   146.0   125.0
# 11  'M1600850729'   123.0    93.0
# 0   'M1053599405'   112.0    97.0
#
# 🌟 Eligible DEI-NEEDED merchants:
# Empty DataFrame
# Columns: [merchant, F, M]
# Index: []
#
# 📦 Processing: chunk_5_20250624_202542.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F       M
# 29   'M348934600'  1316.0  1090.0
# 17  'M1823072687'   599.0   480.0
# 42   'M855959430'   438.0   369.0
# 9    'M151143676'   431.0   374.0
# 44    'M85975013'   368.0   309.0
# 26   'M209847108'   281.0   212.0
# 33   'M480139044'   221.0   161.0
# 10  'M1535107174'   172.0   140.0
# 11  'M1600850729'   152.0   116.0
# 0   'M1053599405'   133.0   114.0
#
# 🌟 Eligible DEI-NEEDED merchants:
# Empty DataFrame
# Columns: [merchant, F, M]
# Index: []
#
# 📦 Processing: chunk_6_20250624_202544.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F       M
# 30   'M348934600'  1348.0  1116.0
# 18  'M1823072687'   659.0   528.0
# 43   'M855959430'   519.0   405.0
# 9    'M151143676'   487.0   424.0
# 45    'M85975013'   428.0   354.0
# 27   'M209847108'   335.0   243.0
# 34   'M480139044'   249.0   182.0
# 10  'M1535107174'   197.0   163.0
# 11  'M1600850729'   178.0   145.0
# 0   'M1053599405'   160.0   130.0
#
# 🌟 Eligible DEI-NEEDED merchants:
#          merchant      F      M
# 24  'M1946091778'  110.0  113.0
# ✅ Wrote 1 detections to outputs//detections_pat3_20250628_195513_178404.csv
#
# 📦 Processing: chunk_7_20250624_202546.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F       M
# 30   'M348934600'  1384.0  1153.0
# 18  'M1823072687'   714.0   580.0
# 43   'M855959430'   566.0   455.0
# 9    'M151143676'   547.0   464.0
# 45    'M85975013'   492.0   402.0
# 27   'M209847108'   374.0   277.0
# 34   'M480139044'   283.0   200.0
# 10  'M1535107174'   220.0   188.0
# 11  'M1600850729'   209.0   168.0
# 0   'M1053599405'   192.0   145.0
#
# 🌟 Eligible DEI-NEEDED merchants:
#          merchant      F      M
# 24  'M1946091778'  132.0  135.0
#
# 📦 Processing: chunk_8_20250624_202548.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F       M
# 30   'M348934600'  1428.0  1194.0
# 18  'M1823072687'   764.0   623.0
# 43   'M855959430'   633.0   508.0
# 9    'M151143676'   589.0   515.0
# 45    'M85975013'   541.0   445.0
# 27   'M209847108'   409.0   310.0
# 34   'M480139044'   321.0   220.0
# 10  'M1535107174'   246.0   200.0
# 11  'M1600850729'   236.0   186.0
# 0   'M1053599405'   222.0   174.0
#
# 🌟 Eligible DEI-NEEDED merchants:
#          merchant      F      M
# 24  'M1946091778'  166.0  168.0
# 31   'M349281107'  107.0  108.0
# ✅ Wrote 1 detections to outputs//detections_pat3_20250628_195513_380522.csv
#
# 📦 Processing: chunk_9_20250624_202550.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F       M
# 30   'M348934600'  1476.0  1226.0
# 18  'M1823072687'   812.0   659.0
# 43   'M855959430'   692.0   560.0
# 9    'M151143676'   635.0   549.0
# 45    'M85975013'   601.0   493.0
# 27   'M209847108'   452.0   345.0
# 34   'M480139044'   355.0   236.0
# 11  'M1600850729'   265.0   207.0
# 10  'M1535107174'   263.0   208.0
# 0   'M1053599405'   249.0   201.0
#
# 🌟 Eligible DEI-NEEDED merchants:
# Empty DataFrame
# Columns: [merchant, F, M]
# Index: []
#
# 📦 Processing: chunk_10_20250624_202551.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F       M
# 30   'M348934600'  1509.0  1254.0
# 18  'M1823072687'   857.0   695.0
# 43   'M855959430'   744.0   617.0
# 9    'M151143676'   685.0   581.0
# 45    'M85975013'   646.0   535.0
# 27   'M209847108'   488.0   376.0
# 34   'M480139044'   378.0   256.0
# 11  'M1600850729'   287.0   228.0
# 0   'M1053599405'   285.0   228.0
# 10  'M1535107174'   279.0   215.0
#
# 🌟 Eligible DEI-NEEDED merchants:
# Empty DataFrame
# Columns: [merchant, F, M]
# Index: []
#
# 📦 Processing: chunk_11_20250624_202553.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F       M
# 30   'M348934600'  1539.0  1281.0
# 18  'M1823072687'   900.0   743.0
# 43   'M855959430'   788.0   667.0
# 9    'M151143676'   734.0   613.0
# 45    'M85975013'   690.0   570.0
# 27   'M209847108'   518.0   401.0
# 34   'M480139044'   402.0   267.0
# 0   'M1053599405'   324.0   257.0
# 11  'M1600850729'   309.0   252.0
# 10  'M1535107174'   298.0   227.0
#
# 🌟 Eligible DEI-NEEDED merchants:
# Empty DataFrame
# Columns: [merchant, F, M]
# Index: []
#
# 📦 Processing: chunk_12_20250624_202555.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F       M
# 30   'M348934600'  
0
#
# 🌟 Eligible DEI-NEEDED merchants:
# Empty DataFrame
# Columns: [merchant, F, M]
# Index: []
#
# 📦 Processing: chunk_55_20250624_202719.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F       M
# 30   'M348934600'  2119.0  1751.0
# 18  'M1823072687'  1900.0  1594.0
# 45    'M85975013'  1816.0  1518.0
# 43   'M855959430'  1565.0  1303.0
# 0   'M1053599405'  1498.0  1194.0
# 9    'M151143676'  1469.0  1197.0
# 24  'M1946091778'  1348.0  1179.0
# 27   'M209847108'  1151.0   952.0
# 11  'M1600850729'  1024.0   849.0
# 31   'M349281107'   970.0   780.0
#
# 🌟 Eligible DEI-NEEDED merchants:
# Empty DataFrame
# Columns: [merchant, F, M]
# Index: []
#
# 📦 Processing: chunk_56_20250624_202721.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F       M
# 30   'M348934600'  2124.0  1754.0
# 18  'M1823072687'  1912.0  1598.0
# 45    'M85975013'  1831.0  1526.0
# 43   'M855959430'  1570.0  1308.0
# 0   'M1053599405'  1513.0  1207.0
# 9    'M151143676'  1473.0  1206.0
# 24  'M1946091778'  1360.0  1194.0
# 27   'M209847108'  1159.0   957.0
# 11  'M1600850729'  1039.0   855.0
# 23  'M1913465890'   984.0   777.0
#
# 🌟 Eligible DEI-NEEDED merchants:
# Empty DataFrame
# Columns: [merchant, F, M]
# Index: []
#
# 📦 Processing: chunk_57_20250624_202722.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F       M
# 30   'M348934600'  2129.0  1758.0
# 18  'M1823072687'  1919.0  1600.0
# 45    'M85975013'  1841.0  1535.0
# 43   'M855959430'  1577.0  1315.0
# 0   'M1053599405'  1534.0  1219.0
# 9    'M151143676'  1480.0  1213.0
# 24  'M1946091778'  1385.0  1207.0
# 27   'M209847108'  1165.0   963.0
# 11  'M1600850729'  1049.0   863.0
# 23  'M1913465890'  1006.0   794.0
#
# 🌟 Eligible DEI-NEEDED merchants:
# Empty DataFrame
# Columns: [merchant, F, M]
# Index: []
#
# 📦 Processing: chunk_58_20250624_202724.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F       M
# 30   'M348934600'  2139.0  1767.0
# 18  'M1823072687'  1929.0  1608.0
# 45    'M85975013'  1855.0  1550.0
# 43   'M855959430'  1582.0  1322.0
# 0   'M1053599405'  1550.0  1232.0
# 9    'M151143676'  1486.0  1218.0
# 24  'M1946091778'  1400.0  1221.0
# 27   'M209847108'  1176.0   969.0
# 11  'M1600850729'  1063.0   872.0
# 23  'M1913465890'  1033.0   816.0
#
# 🌟 Eligible DEI-NEEDED merchants:
# Empty DataFrame
# Columns: [merchant, F, M]
# Index: []
#
# 📦 Processing: chunk_59_20250624_202726.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F       M
# 30   'M348934600'  2142.0  1771.0
# 18  'M1823072687'  1939.0  1612.0
# 45    'M85975013'  1865.0  1557.0
# 43   'M855959430'  1593.0  1328.0
# 0   'M1053599405'  1561.0  1245.0
# 9    'M151143676'  1493.0  1223.0
# 24  'M1946091778'  1417.0  1235.0
# 27   'M209847108'  1180.0   974.0
# 11  'M1600850729'  1071.0   876.0
# 23  'M1913465890'  1050.0   842.0
#
# 🌟 Eligible DEI-NEEDED merchants:
# Empty DataFrame
# Columns: [merchant, F, M]
# Index: []
#
# 📦 Processing: chunk_60_20250624_202728.csv
#
# ✅ No gender conflicts found.
#
# 📟 Gender distribution per merchant (top 10):
#          merchant       F       M
# 30   'M348934600'  2147.0  1771.0
# 18  'M1823072687'  1945.0  1617.0
# 45    'M85975013'  1870.0  1561.0
# 43   'M855959430'  1594.0  1329.0
# 0   'M1053599405'  1571.0  1248.0
# 9    'M151143676'  1497.0  1226.0
# 24  'M1946091778'  1426.0  1241.0
# 27   'M209847108'  1183.0   974.0
# 11  'M1600850729'  1079.0   878.0
# 23  'M1913465890'  1062.0   844.0
#
# 🌟 Eligible DEI-NEEDED merchants:
#         merchant      F      M
# 38  'M677738360'  173.0  174.0
# ✅ Wrote 1 detections to outputs//detections_pat3_20250628_195521_284663.csv
